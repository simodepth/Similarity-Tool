# %% [markdown]
# <a href="https://colab.research.google.com/github/simodepth/Similarity-Tool/blob/main/Snippet_Similarity_with_Top_Queries_with_Sentence_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1> Strike the Snippet Similarity based on Search Queries </h1>
#
# > <h2> What this framework does</h2>
# <p>
# We have a corpus with various sentences. Then, for a given query sentence,
# we want to find the most similar sentence in this corpus.
# This script outputs for various queries the top 5 most similar sentences in the corpus.
# </p>
#
# > <h2> Reference </h2>
# https://github.com/UKPLab/sentence-transformers/blob/master/examples/applications/semantic-search/semantic_search.py

# %%
# !pip install sentence_transformers
# !pip install ecommercetools
# !pip install google-search-results
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 4.5 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.23.1-py3-none-any.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 61.4 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.13.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 57.9 MB/s
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 55.8 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.8.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.13.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence_transformers) (3.0.9)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 45.2 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.6.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence_transformers) (3.9.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=016f87e28c9f20d4b687dba69e841b657b9b0619e09eb74efed1b9a42dfda8ff
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, huggingface-hub, transformers, sentencepiece, sentence-transformers
# Successfully installed huggingface-hub-0.10.1 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.1 transformers-4.23.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ecommercetools
#   Downloading ecommercetools-0.42.4-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 2.7 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (1.3.5)
# Requirement already satisfied: httplib2>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (0.17.4)
# Collecting lifetimes
#   Downloading Lifetimes-0.11.3-py3-none-any.whl (584 kB)
#      |████████████████████████████████| 584 kB 38.9 MB/s
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (4.23.1)
# Collecting pycausalimpact
#   Downloading pycausalimpact-0.1.1-py2.py3-none-any.whl (30 kB)
# Collecting gapandas
#   Downloading gapandas-1.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (1.21.6)
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (1.12.1+cu113)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (2.23.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from gapandas->ecommercetools) (4.1.3)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.7/dist-packages (from gapandas->ecommercetools) (1.12.11)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (3.0.1)
# Requirement already satisfied: six<2dev,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (1.15.0)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (1.35.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (0.0.4)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (1.31.6)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (57.4.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (2022.4)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (3.17.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (21.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (1.56.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (1.24.3)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from lifetimes->ecommercetools) (1.7.3)
# Requirement already satisfied: dill>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from lifetimes->ecommercetools) (0.3.5.1)
# Requirement already satisfied: autograd>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from lifetimes->ecommercetools) (1.5)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.2.0->lifetimes->ecommercetools) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ecommercetools) (2.8.2)
# Requirement already satisfied: jinja2>=2.10 in /usr/local/lib/python3.7/dist-packages (from pycausalimpact->ecommercetools) (2.11.3)
# Requirement already satisfied: statsmodels>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from pycausalimpact->ecommercetools) (0.12.2)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.7/dist-packages (from pycausalimpact->ecommercetools) (3.2.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.10->pycausalimpact->ecommercetools) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.2.3->pycausalimpact->ecommercetools) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.2.3->pycausalimpact->ecommercetools) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=2.2.3->pycausalimpact->ecommercetools) (4.1.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.11.0->pycausalimpact->ecommercetools) (0.5.3)
# Collecting w3lib
#   Downloading w3lib-2.0.1-py3-none-any.whl (20 kB)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->ecommercetools) (0.0.1)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.9 MB/s
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (4.13.0)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 54.0 MB/s
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (112 kB)
#      |████████████████████████████████| 112 kB 57.2 MB/s
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (4.64.1)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (1.4.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->ecommercetools) (3.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->ecommercetools) (4.6.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->ecommercetools) (4.9.1)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->ecommercetools) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->ecommercetools) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->ecommercetools) (3.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (2022.6.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (0.10.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (0.13.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (3.8.0)
# Building wheels for collected packages: fake-useragent, parse, sklearn
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=89bdb4927cba25f98f1e8b4b5af566ca75e0f79da37199f02f8b847f77ae6624
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=0f0659ceb04ab1d11ad49a0ea0f50ac7915856e5406b8b50e8e4c1f5154b97d5
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=84e2722b64c1fd78bc1b50063027fc34fb7d190265b9892116ef331df5ef2465
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built fake-useragent parse sklearn
# Installing collected packages: urllib3, websockets, pyee, cssselect, w3lib, pyquery, pyppeteer, parse, fake-useragent, sklearn, requests-html, pycausalimpact, lifetimes, gapandas, ecommercetools
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed cssselect-1.1.0 ecommercetools-0.42.4 fake-useragent-0.1.11 gapandas-1.0 lifetimes-0.11.3 parse-1.19.0 pycausalimpact-0.1.1 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 requests-html-0.10.0 sklearn-0.0 urllib3-1.25.11 w3lib-2.0.1 websockets-10.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-search-results
#   Downloading google_search_results-2.4.1.tar.gz (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from google-search-results) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->google-search-results) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->google-search-results) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->google-search-results) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->google-search-results) (2022.9.24)
# Building wheels for collected packages: google-search-results
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.1-py3-none-any.whl size=25789 sha256=c3c2e484ad3d26fa5647ed4b3e3243fa3be5861739bdefcbf46ef8cd0ce095d7
#   Stored in directory: /root/.cache/pip/wheels/82/a3/c5/364155118f298722dff2f79ae4dd7c91e92b433ad36d6f7e0e
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.1

# %%
from sentence_transformers import SentenceTransformer, util
import torch

#scraping
import requests
from serpapi import GoogleSearch
import urllib
import urllib.parse
import json
from urllib.parse import (parse_qsl, urlsplit)
from requests_html import HTML
from requests_html import HTMLSession


#data manipulation
import pandas as pd
import numpy as np


#libraries for preprocessing tasks
from gensim.parsing.preprocessing import remove_stopwords
import string
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize


#Download once if using NLTK for preprocessing
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def get_source(url):

    try:
        session = HTMLSession()
        response = session.get(url)
        return response
    except requests.exceptions.RequestException as e:
        print(e)

def get_results(query):
    query = urllib.parse.quote_plus(query)
    response = get_source("https://suggestqueries.google.com/complete/search?output=chrome&hl=en&q=" + query)
    results = json.loads(response.text)
    return results

# %%
from ecommercetools import seo
import pandas as pd

suggestions = seo.google_autocomplete('coffee', include_expanded=True)
queries = pd.DataFrame(suggestions)
queries.to_csv('queries.csv')
queries.head(10)
# Out:
#                         term  relevance
# 0             coffee near me       1250
# 1        cheap coffee tables       1250
# 2    when coffee meets bagel       1250
# 3  why coffee makes you poop       1250
# 4         how coffee is made       1250
# 5                coffee bean       1250
# 6               coffee jelly       1250
# 7         coffee meets bagel       1250
# 8             coffee near me       1250
# 9              coffee quotes       1250

# %%
results = queries.drop_duplicates('term')
results.to_csv('results.csv')
results.head(10)
# Out:
#                          term  relevance
# 0              coffee near me       1250
# 1         cheap coffee tables       1250
# 2     when coffee meets bagel       1250
# 3   why coffee makes you poop       1250
# 4          how coffee is made       1250
# 5                 coffee bean       1250
# 6                coffee jelly       1250
# 7          coffee meets bagel       1250
# 9               coffee quotes       1250
# 10   coffee request crossword       1250

# %%
from serpapi import GoogleSearch

serp_apikey = "######" 

params = {
    "engine": "google",
    "q": "coffee",
    "location": "United Kingdom",
    "google_domain": "google.com",
    "gl": "uk",
    "hl": "en",
    "num": 10,
    "api_key": serp_apikey
}

client = GoogleSearch(params)
data = client.get_dict()

# access "organic results"
df = pd.DataFrame(data['organic_results'])
df.to_csv('results_1.csv', index=False)
df
# Out:
# https://serpapi.com/search
#    position                                              title  \
# 0         1                                 Coffee - Wikipedia
# 1         2                                Starbucks: Homepage
# 2         3  Coffee Beans | Blended Coffee | Whittard of Ch...
# 3         4   Costa Coffee: The Nation's Favourite Coffee Shop
# 4         5  Origin Coffee Roasters: Speciality Coffee Onli...
# 5         6  Pact Coffee: The UK's Best Coffee Delivery & S...
# 6         7                      Coffee | The Nutrition Source
# 7         8   Coffee Beans: Where Do They Come From? | Nescafé
# 8         9      Coffee Beans – Best in the UK - Coffee-Direct
#
#                                                 link  \
# 0               https://en.wikipedia.org/wiki/Coffee
# 1                       https://www.starbucks.co.uk/
# 2                  https://www.whittard.co.uk/coffee
# 3                           https://www.costa.co.uk/
# 4                    https://www.origincoffee.co.uk/
# 5                        https://www.pactcoffee.com/
# 6  https://www.hsph.harvard.edu/nutritionsource/f...
# 7  https://www.nescafe.com/gb/understanding-coffe...
# 8  https://www.coffee-direct.co.uk/collections/al...
#
#                                       displayed_link  \
# 0           https://en.wikipedia.org › wiki › Coffee
# 1                        https://www.starbucks.co.uk
# 2                https://www.whittard.co.uk › coffee
# 3                            https://www.costa.co.uk
# 4                     https://www.origincoffee.co.uk
# 5                         https://www.pactcoffee.com
# 6  https://www.hsph.harvard.edu › ... › Food Feat...
# 7  https://www.nescafe.com › Home › Understanding...
# 8  https://www.coffee-direct.co.uk › collections ...
#
#                                            thumbnail  \
# 0  https://serpapi.com/searches/6357e004216a9d3cd...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                              snippet  \
# 0  Coffee is a drink prepared from roasted coffee...
# 1  About us. About Us · Our Coffees · Starbucks S...
# 2  Whether you prefer whole coffee beans or fresh...
# 3  Costa is the Nation's Favourite coffee shop an...
# 4  Leading UK speciality coffee roaster with a fo...
# 5  Kick-start your morning with our amazing range...
# 6  Coffee beans are the seeds of a fruit called a...
# 7  On these coffee plants, bunches of cherries gr...
# 8  Coffee Beans. Browse through our entire range ...
#
#           snippet_highlighted_words  \
# 0          [Coffee, coffee, coffee]
# 1                 [Coffees, Coffee]
# 2         [coffee, coffee, coffees]
# 3                  [coffee, coffee]
# 4                  [coffee, coffee]
# 5                  [coffee, coffee]
# 6  [Coffee, coffee, Coffee, coffee]
# 7  [coffee, coffee, coffee, coffee]
# 8                 [Coffee, coffees]
#
#                                            sitelinks  \
# 0  {'inline': [{'title': 'Coffee bean', 'link': '...
# 1                                                NaN
# 2  {'inline': [{'title': 'All Coffee', 'link': 'h...
# 3                                                NaN
# 4  {'inline': [{'title': 'Speciality Coffee', 'li...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
#
#                                         rich_snippet  \
# 0  {'bottom': {'extensions': ['Region of origin: ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
#
#                                    about_this_result  \
# 0  {'source': {'description': 'Wikipedia is a mul...
# 1  {'source': {'description': 'Starbucks Corporat...
# 2  {'source': {'description': 'Whittard of Chelse...
# 3  {'source': {'description': 'Costa Coffee is a ...
# 4  {'source': {'description': 'origincoffee.co.uk...
# 5  {'source': {'description': 'pactcoffee.com was...
# 6  {'source': {'description': 'The Harvard T.H. C...
# 7  {'source': {'description': 'This result comes ...
# 8  {'source': {'description': 'coffee-direct.co.u...
#
#                                      about_page_link  \
# 0  https://www.google.com/search?q=About+https://...
# 1  https://www.google.com/search?q=About+https://...
# 2  https://www.google.com/search?q=About+https://...
# 3  https://www.google.com/search?q=About+https://...
# 4  https://www.google.com/search?q=About+https://...
# 5  https://www.google.com/search?q=About+https://...
# 6  https://www.google.com/search?q=About+https://...
# 7  https://www.google.com/search?q=About+https://...
# 8  https://www.google.com/search?q=About+https://...
#
#                              about_page_serpapi_link  \
# 0  https://serpapi.com/search.json?engine=google_...
# 1  https://serpapi.com/search.json?engine=google_...
# 2  https://serpapi.com/search.json?engine=google_...
# 3  https://serpapi.com/search.json?engine=google_...
# 4  https://serpapi.com/search.json?engine=google_...
# 5  https://serpapi.com/search.json?engine=google_...
# 6  https://serpapi.com/search.json?engine=google_...
# 7  https://serpapi.com/search.json?engine=google_...
# 8  https://serpapi.com/search.json?engine=google_...
#
#                                     cached_page_link  \
# 0  https://webcache.googleusercontent.com/search?...
# 1  https://webcache.googleusercontent.com/search?...
# 2  https://webcache.googleusercontent.com/search?...
# 3  https://webcache.googleusercontent.com/search?...
# 4  https://webcache.googleusercontent.com/search?...
# 5  https://webcache.googleusercontent.com/search?...
# 6  https://webcache.googleusercontent.com/search?...
# 7  https://webcache.googleusercontent.com/search?...
# 8  https://webcache.googleusercontent.com/search?...
#
#                                   related_pages_link         date
# 0  https://www.google.com/search?gl=uk&hl=en&q=re...          NaN
# 1  https://www.google.com/search?gl=uk&hl=en&q=re...          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4  https://www.google.com/search?gl=uk&hl=en&q=re...          NaN
# 5  https://www.google.com/search?gl=uk&hl=en&q=re...          NaN
# 6                                                NaN          NaN
# 7                                                NaN          NaN
# 8  https://www.google.com/search?gl=uk&hl=en&q=re...  116 results

# %%
SERP_One = pd.read_csv('/content/results_1.csv')
Snippet = pd.DataFrame(SERP_One, columns=['snippet'])
Snippet.to_csv('corpus.csv', index=False)
Snippet
# Out:
#                                              snippet
# 0  Coffee is a drink prepared from roasted coffee...
# 1  About us. About Us · Our Coffees · Starbucks S...
# 2  Whether you prefer whole coffee beans or fresh...
# 3  Costa is the Nation's Favourite coffee shop an...
# 4  Leading UK speciality coffee roaster with a fo...
# 5  Kick-start your morning with our amazing range...
# 6  Coffee beans are the seeds of a fruit called a...
# 7  On these coffee plants, bunches of cherries gr...
# 8  Coffee Beans. Browse through our entire range ...

# %%
embedder = SentenceTransformer('all-MiniLM-L6-v2')

corpus = [
    'About us. About Us · Our Coffees · Starbucks Stories & News · Starbucks® Ready to Drink · Foodservice Coffee · Customer Service · Tax Strategy 2022 · Careers.',
    'Costa is the Nation Favourite coffee shop and the largest and fastest growing coffee shop chain in the UK.',
    'Leading UK speciality coffee roaster with a focus on sustainability. B Corp certified. Become a wholesale partner or buy coffee beans online today.',
    'Kick-start your morning with our amazing range of speciality coffee and equipment. World-class coffee, direct from the farmer, delivered free every time.',
    'Coffee Direct - Freshly roasted coffee beans delivered to your door. Origin coffee, coffee blends and flavoured coffee for bean-to-cup',
    'Whether you prefer whole coffee beans or freshly ground coffee, Whittard of Chelsea selection of light, medium and dark roast luxury coffees has something',
    'Coffee beans are the seeds of a fruit called a coffee cherry. Coffee cherries grow on coffee trees from a genus of plants called Coffea.',
    'On these coffee plants, bunches of cherries grow and inside these you will find two coffee beans, Arabica and Robusta coffee.',
]
corpus_embeddings = embedder.encode(corpus, convert_to_tensor=True)

# Query sentences:
queries = ['coffee', 'coffee near me', 'coffee bean', 'coffee house', 'coffee jelly', 'coffee order nyt crossword clue',
           'coffee quotes', 'coffee shops near me']

# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
top_k = min(5, len(corpus))
query_result = list()  
for query in queries:
    query_embedding = embedder.encode(query, convert_to_tensor=True)

    cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    for score, idx in zip(top_results[0], top_results[1]):
        corpus[idx], "(Score: {:.4f})".format(score)
        query_result.append([query, corpus[idx], score])

df = pd.DataFrame(query_result,columns=['Query','Snippet','Score']) 
df.to_csv('results.csv',index=False)
df
# Out:
#                               Query  \
# 0                            coffee
# 1                            coffee
# 2                            coffee
# 3                            coffee
# 4                            coffee
# 5                    coffee near me
# 6                    coffee near me
# 7                    coffee near me
# 8                    coffee near me
# 9                    coffee near me
# 10                      coffee bean
# 11                      coffee bean
# 12                      coffee bean
# 13                      coffee bean
# 14                      coffee bean
# 15                     coffee house
# 16                     coffee house
# 17                     coffee house
# 18                     coffee house
# 19                     coffee house
# 20                     coffee jelly
# 21                     coffee jelly
# 22                     coffee jelly
# 23                     coffee jelly
# 24                     coffee jelly
# 25  coffee order nyt crossword clue
# 26  coffee order nyt crossword clue
# 27  coffee order nyt crossword clue
# 28  coffee order nyt crossword clue
# 29  coffee order nyt crossword clue
# 30                    coffee quotes
# 31                    coffee quotes
# 32                    coffee quotes
# 33                    coffee quotes
# 34                    coffee quotes
# 35             coffee shops near me
# 36             coffee shops near me
# 37             coffee shops near me
# 38             coffee shops near me
# 39             coffee shops near me
#
#                                               Snippet           Score
# 0   Coffee Direct - Freshly roasted coffee beans d...  tensor(0.6477)
# 1   Whether you prefer whole coffee beans or fresh...  tensor(0.5873)
# 2   Kick-start your morning with our amazing range...  tensor(0.5739)
# 3   Coffee beans are the seeds of a fruit called a...  tensor(0.4985)
# 4   Costa is the Nation Favourite coffee shop and ...  tensor(0.4374)
# 5   Whether you prefer whole coffee beans or fresh...  tensor(0.5395)
# 6   Kick-start your morning with our amazing range...  tensor(0.5306)
# 7   Coffee Direct - Freshly roasted coffee beans d...  tensor(0.5256)
# 8   Costa is the Nation Favourite coffee shop and ...  tensor(0.4563)
# 9   Coffee beans are the seeds of a fruit called a...  tensor(0.4151)
# 10  Coffee Direct - Freshly roasted coffee beans d...  tensor(0.6698)
# 11  Coffee beans are the seeds of a fruit called a...  tensor(0.6322)
# 12  Whether you prefer whole coffee beans or fresh...  tensor(0.5798)
# 13  Kick-start your morning with our amazing range...  tensor(0.5350)
# 14  On these coffee plants, bunches of cherries gr...  tensor(0.5313)
# 15  Coffee Direct - Freshly roasted coffee beans d...  tensor(0.5288)
# 16  Whether you prefer whole coffee beans or fresh...  tensor(0.5228)
# 17  Kick-start your morning with our amazing range...  tensor(0.5061)
# 18  Costa is the Nation Favourite coffee shop and ...  tensor(0.4787)
# 19  On these coffee plants, bunches of cherries gr...  tensor(0.3827)
# 20  Coffee Direct - Freshly roasted coffee beans d...  tensor(0.4732)
# 21  Whether you prefer whole coffee beans or fresh...  tensor(0.4662)
# 22  Coffee beans are the seeds of a fruit called a...  tensor(0.4290)
# 23  Kick-start your morning with our amazing range...  tensor(0.3935)
# 24  On these coffee plants, bunches of cherries gr...  tensor(0.3564)
# 25  Whether you prefer whole coffee beans or fresh...  tensor(0.4500)
# 26  Coffee Direct - Freshly roasted coffee beans d...  tensor(0.4490)
# 27  Kick-start your morning with our amazing range...  tensor(0.4149)
# 28  Costa is the Nation Favourite coffee shop and ...  tensor(0.3923)
# 29  About us. About Us · Our Coffees · Starbucks S...  tensor(0.3271)
# 30  Coffee Direct - Freshly roasted coffee beans d...  tensor(0.5139)
# 31  Kick-start your morning with our amazing range...  tensor(0.4934)
# 32  Whether you prefer whole coffee beans or fresh...  tensor(0.4834)
# 33  Coffee beans are the seeds of a fruit called a...  tensor(0.4615)
# 34  About us. About Us · Our Coffees · Starbucks S...  tensor(0.4393)
# 35  Costa is the Nation Favourite coffee shop and ...  tensor(0.5684)
# 36  Kick-start your morning with our amazing range...  tensor(0.4778)
# 37  Whether you prefer whole coffee beans or fresh...  tensor(0.4762)
# 38  Coffee Direct - Freshly roasted coffee beans d...  tensor(0.4445)
# 39  On these coffee plants, bunches of cherries gr...  tensor(0.4172)

# %%
#@title  Single out Queries by Rows
query_1 = df.loc[df['Query'] == 'coffee']
query_2 = df.loc[df['Query'] == 'coffee near me']
query_3 = df.loc[df['Query'] == 'coffee bean']
query_4 = df.loc[df['Query'] == 'coffee house']
query_5 = df.loc[df['Query'] == 'coffee jelly']
query_6 = df.loc[df['Query'] == 'coffee order nyt crossword clue']
query_7 = df.loc[df['Query'] == 'coffee quotes']

# %% [markdown]
# ##Choose the Query to visualize the Snippet Similarity on

# %%
query_3.to_csv('coffee bean.csv', index=False)

# %%
Data = pd.read_csv('coffee bean.csv')
Data['Score'] = Data['Score'].str.replace("tensor\(|\)", "")
Data['Score'] = Data['Score'].astype(float)
Data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#          Query                                            Snippet   Score
# 0  coffee bean  Coffee Direct - Freshly roasted coffee beans d...  0.6698
# 1  coffee bean  Coffee beans are the seeds of a fruit called a...  0.6322
# 2  coffee bean  Whether you prefer whole coffee beans or fresh...  0.5798
# 3  coffee bean  Kick-start your morning with our amazing range...  0.5350
# 4  coffee bean  On these coffee plants, bunches of cherries gr...  0.5313
